# %%
from langchain_chroma.vectorstores import Chroma
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

from openevals.llm import create_llm_as_judge
from openevals.prompts import RETRIEVAL_HELPFULNESS_PROMPT

import pandas as pd
import time

# %%
# Initialize embeddings model (ensure the same model used during creation)
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# Load the existing Chroma vector store
persist_directory = "../db/swim_rules_semantic"
vector_store = Chroma(persist_directory=persist_directory, embedding_function=embeddings)

# %% [markdown]
# ## Helper Functions

# %%
# Function to perform semantic search
def semantic_search(query, k=10):
    """
    Perform a semantic search on the Chroma vector store.

    Args:
        query (str): The query string to search for.
        k (int): The number of top results to retrieve.

    Returns:
        list: A list of documents matching the query.
    """
    results = vector_store.similarity_search_with_relevance_scores(query, k=k, score_threshold=0.4)
    chunks = [{"title": f"chunk_{chunk+1}", "content": result[0].page_content} for chunk, result in enumerate(results)]

    relevance = chunk_evaluator(inputs=query, outputs=chunks)

    print(f"num results: {len(results)}, {[result[1] for result in results]}")

    return relevance




chunk_evaluator = create_llm_as_judge(
    prompt=RETRIEVAL_HELPFULNESS_PROMPT,
    feedback_key="retrieval_helpfulness",
    model="openai:gpt-4o",
)

# %% [markdown]
# ## Test chunk retrieval

# %%
# %%time
# Example usage
queries = [
    "Prior to the start signal the swimmer is seen rocking back and forth.  Is this a disqualification?",
    "upon the command 'take your mark', the swimmer takes their starting position and just prior to the start signal, the swimmer is seen moving forward.",
    "What happens if a swimmer touches the wall with one hand in freestyle?",
    "what happens if a swimmer touches the wall with one hand in breaststroke?",
    "A swimmer is wearing a wetsuit in a swimming competition?",
    "During a freestyle event, a swimmer does a flip turn and touches the wall with only one foot.",
    "A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of the first arm stroke, both after the start and after the turn Should they be disqualified?",
    "In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?",
    "In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall on their back to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?",
    "A swimmer swims the breaststroke in a way that their hands are completely underwater when they are pushed forward together from their breast.",
    "A swimmer swims the breaststroke in a way that their elbows are above the water line during the forward movement of the arms.",
    "A breaststroker’s head breaks the surface of the water during each cycle, however, the swimmer does not take a breath even if the head breaks the surface.",
    "During a freestyle event, a swimmer starts in the water such that the swimmwer is facing the starting end of the pool with one hand on the wall.",
    "During a freestyle event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer has one hand on the wall looking away from the starting block.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer is looking at the opposite end of the pool.",
    "In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second 50m in backstroke, the third 50m starts swimming freestyle but then switches to breaststroke, and the last 50m in freestyle.",
    "In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y in backstroke.",
]

relevance_list = []
for i, query in enumerate(queries):
    print(f"\nQuery: {query}")
    start_time = time.time()
    relevance = semantic_search(query)
    end_time = time.time()

    relevance["query"] = query
    relevance["evaluation_time"] = end_time - start_time
    relevance_list.append(relevance)

    print(f"completed {i+1} out of {len(queries)} queries")
# Out:
# Query: Prior to the start signal the swimmer is seen rocking back and forth.  Is this a disqualification?
# num results: 2, [0.43222538948755584, 0.42851414874192906]
# completed 1 out of 19 queries
#
# Query: upon the command 'take your mark', the swimmer takes their starting position and just prior to the start signal, the swimmer is seen moving forward.
# num results: 2, [0.4263217539760894, 0.41741996635412393]
# completed 2 out of 19 queries
#
# Query: What happens if a swimmer touches the wall with one hand in freestyle?
# num results: 3, [0.516105029518711, 0.4516102424042624, 0.4171791753034092]
# completed 3 out of 19 queries
#
# Query: what happens if a swimmer touches the wall with one hand in breaststroke?
# num results: 3, [0.513873848657147, 0.46893478877836237, 0.42539928590273146]
# completed 4 out of 19 queries
#
# Query: A swimmer is wearing a wetsuit in a swimming competition?
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 0, []
# completed 5 out of 19 queries
#
# Query: During a freestyle event, a swimmer does a flip turn and touches the wall with only one foot.
# num results: 1, [0.4583698804089851]
# completed 6 out of 19 queries
#
# Query: A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of the first arm stroke, both after the start and after the turn Should they be disqualified?
# num results: 2, [0.5278120395398984, 0.4294021828400536]
# completed 7 out of 19 queries
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?
# num results: 4, [0.5146909669551838, 0.5091261499588964, 0.48396435495734724, 0.43532050465670646]
# completed 8 out of 19 queries
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall on their back to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?
# num results: 4, [0.5147741648341444, 0.5134805094659509, 0.49748670768673386, 0.4403896252614583]
# completed 9 out of 19 queries
#
# Query: A swimmer swims the breaststroke in a way that their hands are completely underwater when they are pushed forward together from their breast.
# num results: 1, [0.4097855222565371]
# completed 10 out of 19 queries
#
# Query: A swimmer swims the breaststroke in a way that their elbows are above the water line during the forward movement of the arms.
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 0, []
# completed 11 out of 19 queries
#
# Query: A breaststroker’s head breaks the surface of the water during each cycle, however, the swimmer does not take a breath even if the head breaks the surface.
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 0, []
# completed 12 out of 19 queries
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmwer is facing the starting end of the pool with one hand on the wall.
# num results: 5, [0.653508654706495, 0.5076304425989419, 0.47857688255750197, 0.4035777129393675, 0.4009182467983301]
# completed 13 out of 19 queries
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.
# num results: 3, [0.6131516993436479, 0.49439076878251764, 0.443277121732344]
# completed 14 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.
# num results: 3, [0.604294296415654, 0.4548697532275494, 0.44093423305260127]
# completed 15 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer has one hand on the wall looking away from the starting block.
# num results: 4, [0.6109770109969948, 0.45886894124220257, 0.4445723459548685, 0.41662523927343054]
# completed 16 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is looking at the opposite end of the pool.
# num results: 2, [0.452058485279235, 0.40671861559850164]
# completed 17 out of 19 queries
#
# Query: In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second 50m in backstroke, the third 50m starts swimming freestyle but then switches to breaststroke, and the last 50m in freestyle.
# num results: 4, [0.5423546831780368, 0.4186815418654285, 0.4168984351454781, 0.40467390199400877]
# completed 18 out of 19 queries
#
# Query: In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y in backstroke.
# num results: 3, [0.4613298114330566, 0.42678174468073726, 0.41189869961646]
# completed 19 out of 19 queries
# CPU times: user 477 ms, sys: 82 ms, total: 559 ms
# Wall time: 2min 40s

# %%
relevance_df = pd.DataFrame(relevance_list)
relevance_df = relevance_df[["key", "score", "evaluation_time", "query", "comment"]]
relevance_df
# Out:
#                       key  score  evaluation_time  \
# 0   retrieval_helpfulness   True         8.345219
# 1   retrieval_helpfulness   True         9.315105
# 2   retrieval_helpfulness  False        10.236450
# 3   retrieval_helpfulness   True         7.539978
# 4   retrieval_helpfulness  False         3.994451
# 5   retrieval_helpfulness  False         8.748319
# 6   retrieval_helpfulness  False        10.914115
# 7   retrieval_helpfulness   True        10.381962
# 8   retrieval_helpfulness  False        13.418655
# 9   retrieval_helpfulness  False         6.653605
# 10  retrieval_helpfulness  False         3.886310
# 11  retrieval_helpfulness  False         6.455379
# 12  retrieval_helpfulness   True         7.890214
# 13  retrieval_helpfulness   True         7.420667
# 14  retrieval_helpfulness   True        10.327613
# 15  retrieval_helpfulness  False        10.000404
# 16  retrieval_helpfulness   True         7.874783
# 17  retrieval_helpfulness  False         8.563899
# 18  retrieval_helpfulness  False         8.848058
#
#                                                 query  \
# 0   Prior to the start signal the swimmer is seen ...
# 1   upon the command 'take your mark', the swimmer...
# 2   What happens if a swimmer touches the wall wit...
# 3   what happens if a swimmer touches the wall wit...
# 4   A swimmer is wearing a wetsuit in a swimming c...
# 5   During a freestyle event, a swimmer does a fli...
# 6   A breaststroke swimmer moves their hands in a ...
# 7   In a 9-10 100 yard breaststroke event, a swimm...
# 8   In a 9-10 100 yard breaststroke event, a swimm...
# 9   A swimmer swims the breaststroke in a way that...
# 10  A swimmer swims the breaststroke in a way that...
# 11  A breaststroker’s head breaks the surface of t...
# 12  During a freestyle event, a swimmer starts in ...
# 13  During a freestyle event, a swimmer starts in ...
# 14  During a butterfly event, a swimmer starts in ...
# 15  During a butterfly event, a swimmer starts in ...
# 16  During a butterfly event, a swimmer starts in ...
# 17  In a 200m individual medley event, a swimmer s...
# 18  In a 100y freestyle event, the swimmer swims t...
#
#                                               comment
# 0   The input concerns a swimmer rocking back and ...
# 1   After reviewing the input and outputs:\n\n**In...
# 2   The input question asks what happens if a swim...
# 3   In evaluating the outputs against the input qu...
# 4   The task involves evaluating retrieved outputs...
# 5   The input concerns the specifics of the rules ...
# 6   To determine whether a breaststroke swimmer sh...
# 7   The input scenario describes a swimmer inciden...
# 8   In this situation, a swimmer mistakenly treate...
# 9   Upon evaluating the content of 'chunk_1', seve...
# 10  The input describes a swimmer's technique in t...
# 11  The input discusses a scenario in competitive ...
# 12  The input describes a freestyle event where a ...
# 13  The given input describes a particular start p...
# 14  The input describes a situation where a swimme...
# 15  The input describes a specific start condition...
# 16  ### Information Needed to Answer the Input:\n1...
# 17  The task involves determining if the retrieved...
# 18  The input describes a 100-yard freestyle event...

# %%
relevance_df.evaluation_time.sum()
# Out:
# 160.81518626213074

# %%
relevance_df.describe()
# Out:
#        evaluation_time
# count        19.000000
# mean          8.463957
# std           2.297888
# min           3.886310
# 25%           7.480322
# 50%           8.563899
# 75%          10.118427
# max          13.418655

# %%
relevance_df.score.value_counts()
# Out:
# score
# False    11
# True      8
# Name: count, dtype: int64

# %%
import textwrap
for relevance in relevance_list:
    print(f"\nQuery: {textwrap.fill(relevance['query'], width=90,replace_whitespace=False)}")
    print(f">>>Evaluation Time: {relevance['evaluation_time']:.2f} seconds")
    print(f">>>Relevance: {relevance['key']} {relevance['score']},\n{textwrap.fill(relevance['comment'], width=90,replace_whitespace=False)}")
# Out:
# Query: Prior to the start signal the swimmer is seen rocking back and forth.  Is this a
# disqualification?
# >>>Evaluation Time: 8.35 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input concerns a swimmer rocking back and forth before the start signal in competitive
# swimming and whether this action might lead to disqualification. The relevant context here
# is the swimming rules governing what actions or behaviors might be classified as a false
# start or other form of misconduct.
#
# Upon evaluating the outputs:
#
# **Relevant Points
# Identified:**
# 1. **Output chunk_1:**
#    - Discusses starting commands, false starts, and
# situations where swimmers may be disqualified for starting violations.
#    - Contains
# detailed rules about what constitutes a false start and criteria for disqualification for
# such offenses.
#
# 2. **Output chunk_2:**
#    - Explains deliberate delay or misconduct at
# the start.
#    - Specifies that actions like delaying the start can lead to
# disqualification, but the discretion lies with the referee to enforce this on any swimmer.
# - Addresses rules about swimmers appearing at the starting platform on time.
# **Analysis:**
# - **Direct Relevance:** The outputs provide detailed rules concerning
# actions at the start which could potentially lead to disqualification, including rocking
# back and forth, which may be perceived as a delay or misconduct according to described
# guidelines.
# - **Partial Relevance:** Outputs don’t explicitly mention "rocking back and
# forth" but cover similar contexts of pre-start actions that the referee and starter might
# consider as signs of misconduct or delay.
#
# **Conclusion:** The retrieved outputs
# contribute useful and directly related information to determine whether the pre-start
# behavior (rocking back and forth) could result in disqualification. Definitions and rules
# concerning false starts and misconduct are well covered.
#
# Thus, the score should be:
# true.
#
# Query: upon the command 'take your mark', the swimmer takes their starting position and just
# prior to the start signal, the swimmer is seen moving forward.
# >>>Evaluation Time: 9.32 seconds
# >>>Relevance: retrieval_helpfulness True,
# After reviewing the input and outputs:
#
# **Input:** The input describes a scenario where,
# just before the start signal, a swimmer is seen moving forward after taking their starting
# position upon the command "take your mark."
#
# **Relevant Context:**
# - The input implies a
# potential false start or illegal movement before the actual start signal.
# - Rules around
# starting positions, when a starter should issue a "stand" command, and what constitutes a
# false start are relevant here.
#
# **Analysis of Outputs:**
#
# 1. **chunk_1 Analysis:**
#    -
# **Relevant Information:**
#      - Describes the starting position command "take your marks"
# and details when a "stand" command is issued if movement occurs. This is directly related
# to the input scenario.
#      - Discusses false starts and the conditions under which a
# swimmer might be disqualified, which directly ties into the input's context about movement
# before the start.
#    - **Partial Relevance/Completeness:**
#      - Although it provides
# comprehensive details on false starts and the starting procedure, it doesn't explicitly
# describe what happens if a swimmer moves but then stops before the signal (e.g., not
# leading to a false start).
#
# 2. **chunk_2 Analysis:**
#    - **Partly Relevant Information:**
# - Provides rules about proper starting position if starting in the water, which adds
# context but doesn't directly address the situation in typical dry-start conditions
# described in the input.
#    - **Irrelevant Information:**
#      - This output only connects
# loosely to the input's context as it focuses on in-water starts and the proper positioning
# rather than movement after assuming a mark.
#
# **Conclusion:**
# - **Complete Relevance:**
# chunk_1 provides directly relevant rules and conditions that align with the input scenario
# on false starts and handling movements after the command "take your mark."
# - **Partial
# Relevance:** chunk_2 does not address the specific conditions of the dry start but offers
# generic context regarding a starting position, which could be applied in some scenarios.
# Thus, the score should be: TRUE.
#
# Query: What happens if a swimmer touches the wall with one hand in freestyle?
# >>>Evaluation Time: 10.24 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input question asks what happens if a swimmer touches the wall with one hand in
# freestyle. Freediving rules often request the swimmer to touch the wall during turns or
# when finishing the race. Looking at the retrieved documents:
#
# 1. **chunk_1** does not
# address the query about freestyle touching the wall with one hand — it discusses starts
# and makes no mention of freestyle.
#    - *Relevance*: Not relevant.
#
# 2. **chunk_2**
# mentions that in freestyle (101.5), "some part of the swimmer must break the surface
# throughout the race." It states for the finish that "the swimmer shall have finished the
# race when any part of his person touches the wall after completing the prescribed
# distance." However, it doesn't stipulate the need for both hands at the turn.
#    -
# *Relevance*: Partially relevant.
#
# 3. **chunk_3** primarily addresses regulations around
# backstroke and butterfly, detailing their specific touch requirements, such as "touch
# shall be made with both hands" for butterfly. It does not provide details for one-hand
# touches in freestyle specifically.
#    - *Relevance*: Not relevant.
#
# ### Conclusion:
# **chunk_2** provides limited information, helping partially confirm that a touch must
# occur in freestyle but does not specifically clarify handling with one hand. The other
# chunks are not relevant, nor do they address the hand-touch aspect. Thus, the retrieved
# outputs do not collectively provide comprehensive or sufficient responses related directly
# to the input question.
#
# Thus, the score should be: false.
#
# Query: what happens if a swimmer touches the wall with one hand in breaststroke?
# >>>Evaluation Time: 7.54 seconds
# >>>Relevance: retrieval_helpfulness True,
# In evaluating the outputs against the input query about the specific rule in breaststroke
# where a swimmer touches the wall with one hand, the following observations were made:
#
# 1.
# **Input Understanding**:
#    - A query seeking clarification on rules about a swimmer
# touching the wall with one hand in breaststroke.
#    - Relevant context needed: touch rules
# during turns and finishes in breaststroke.
#
# 2. **Outputs Evaluation**:
#
#    - **Chunk
# 1**: Contains information about starting procedures, with no mention of turns or finishes
# relevant to the breaststroke.
#      - *Irrelevant*.
#
#    - **Chunk 2**: Contains rules
# for butterfly and backstroke, along with a mention of breaststroke turn regulations.
# - References relevant information on how touches should be made with both hands
# simultaneously in breaststroke, found under '22 101.2'. However, some superfluous
# information was provided about other strokes and starting procedures.
#      - *Relevant
# with partially useful information*.
#
#    - **Chunk 3**: Provides details under '101.2'
# specific to breaststroke regarding start and stroke cycles.
#      - Mentions that both
# hands must touch simultaneously during turns and finishes.
#      - Provides relevant
# context necessary to answer the input query about hand touches not being compliant.
#      -
# *Highly relevant*.
#
# 3. **Conclusion**:
#    - The first chunk is irrelevant to answering the
# question,
#    - The second and third chunks provide information directly addressing the
# rule related to how touches must be made in breaststroke, supporting a comprehensive
# understanding of the rules and clarifying that touching with one hand could potentially
# lead to disqualification as both hands must touch simultaneously.
#
# Thus, the score should
# be: true.
#
# Query: A swimmer is wearing a wetsuit in a swimming competition?
# >>>Evaluation Time: 3.99 seconds
# >>>Relevance: retrieval_helpfulness False,
# The task involves evaluating retrieved outputs for their relevance and utility in
# answering the input question about a swimmer wearing a wetsuit in a swimming competition.
# The input implies a query regarding regulations, benefits, or implications of wearing a
# wetsuit during a swim competition. Relevant context might include official competition
# rules, benefits of wearing a wetsuit, or common practices in such competitions.
#
# Upon
# assessing the output, which is an empty array, it's clear there are no retrieved documents
# or outputs present to evaluate. Thus, there is no information provided that could
# potentially aid the analysis or response to the input query.
#
# Given that there is no
# retrieved information at all, the lack of output fails to satisfy the primary criteria
# outlined in the rubric for relevance (information that could help answer the input or even
# somewhat related information).
#
# Thus, the score should be: false.
#
# Query: During a freestyle event, a swimmer does a flip turn and touches the wall with only one
# foot.
# >>>Evaluation Time: 8.75 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input concerns the specifics of the rules governing flip turns and wall touches during
# a freestyle swimming event, particularly focusing on whether touching the wall with only
# one foot is sufficient. This falls under the criteria of swimming regulations and
# technique, mainly focusing on turns during freestyle events.
#
# **Identified Facts and
# Relevant Context:**
# 1. During a freestyle event, swimmers often perform flip turns where
# touching the wall is crucial.
# 2. The rules should clarify what part of the swimmer must
# contact the wall during a turn, specifically in freestyle.
# 3. The relevance of a single
# foot touch versus other part requirements (like hands) is central to adjudging compliance.
# **Analysis of the Retrieved Document:**
# - The retrieved document contains general
# regulatory information on swimming rules, including a detailed breakdown of both turns and
# finishes across different strokes. However, only a part seems to address aspects relevant
# to the input.
# - The document explains aspects about touching the wall during turns: "Upon
# completion of each length, the swimmer must touch the wall." It does not specify the
# required body part, however, leaving ambiguity regarding the specific query about a single
# foot touch.
# - Importantly, the document addresses the freestyle beyond the mentioned
# point, explaining turn-related submersions and recovery to the swim stroke, but not
# specifically touching nuances detailed in the input.
#
# **Level of Address:**
# - **Partially
# Addressed:**
#   - The requirement of wall touch during turns is noted, but the specificity
# about only one foot making the touch is unclear. This is a partial addressing of the
# input, requiring further specification not found in the document.
#
# **Missing
# Information:**
# - No explicit details or specifics were found about whether one foot is a
# sufficient wall touch.
#
# **Conclusion:**
# The retrieved document contains some contextual
# information on freestyle rules and turning requirements but lacks specificity in
# addressing the critical detail (foot touch) fully and explicitly required by the input.
# Thus, the score should be: False.
#
# Query: A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of
# the first arm stroke, both after the start and after the turn Should they be disqualified?
# >>>Evaluation Time: 10.91 seconds
# >>>Relevance: retrieval_helpfulness False,
# To determine whether a breaststroke swimmer should be disqualified for using a sculling or
# flipper movement at the end of the first arm stroke, both after the start and after the
# turn, it is essential to reference the rules governing the breaststroke. The input focuses
# on evaluating a specific scenario against the regulations of the breaststroke.
#
# First, the
# evaluation must consider the key aspects of the breaststroke as outlined in the given
# outputs:
# - The movements of the arms must be simultaneous without alternating movement.
# -
# It is allowed for hands to be brought back on or under the surface but not beyond the hip
# line, except during the first stroke after the start and each turn.
# - The stroke cycle
# consists of one arm stroke and one leg kick in that order.
#
# The retrieved outputs explain
# the rules of the breaststroke but do not explicitly mention the sculling or flipper
# movement, nor do they specifically address whether such movements are grounds for
# disqualification. However, the alignment of specific moves with the prescribed rule
# requirements could help infer the rule's stance.
# - **Relevant Information**: The outputs
# thoroughly explain the required strokes and movements in breaststroke, particularly the
# synchrony of arm movements and the restrictions on how arms may move after the start and
# turn.
# - **Partially Relevant Information**: The explanation of swimming strokes other than
# breaststroke, like butterfly and backstroke, can be partially relevant for broader context
# but doesn't directly address the query.
# - **Irrelevant Information**: Information about
# disqualification for other technicalities, like delayed start, does not relate directly to
# the arm movements in question.
#
# Thus, the given outputs provide rules that can be used to
# address potential disqualification issues indirectly. However, they do not directly cite
# the scenario of sculling or flipper movements.
#
# Thus, the score should be: false.
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous
# two-hand touch and, thinking that the race is over, pushes back from the wall to read the
# scoreboard. At this point, realizing that the race is only halfway over, the swimmer
# returns to the wall, pushes off on the breast, and completes the required distance in good
# form. What call, if any, should be made?
# >>>Evaluation Time: 10.38 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input scenario describes a swimmer incident during a breaststroke event, where a
# swimmer mistakenly believes the race is over after the first 50 yards, observes the
# scoreboard, then realizes and completes the race adhering to the rules for the remaining
# distance.
#
# The primary rules for the breaststroke regarding turns and finishes can be
# pivotal in determining the appropriate call:
# 1. **Turn Regulations**: The retrieved
# documents emphasize the requirement for a simultaneous two-hand touch upon completion of
# each length, which the swimmer adhered to at the 50-yard mark.
# 2. **Forward Push from the
# Wall**: They inaccurately initiated an unsanctioned backward push from the wall before
# returning and completing the turn in a corrected, legal form as needed under Section 101.2
# Turns and Finish.
# 3. **Overall Stroke and Technique**: The documents stipulate
# breaststroke-specific regulations that restrict alternating leg and arm motions and
# underwater submersion beyond set distances, none of which were violated during the latter
# half of the race.
#
# Analyzing the rules and reports, it appears the voluntary backward push
# without further swimming actions or undue advantage may be construed as an unintended
# infraction but not necessarily grounds for a disqualification, particularly since
# corrections were promptly made without further penalties or intentional misconduct due per
# 101.2 regulations, specifically relating to turns where completion was legal.
#
# Thus, the
# score should be: True, as the retrieved outputs contain relevant documentation focusing on
# stroke and turn requirements applicable to the query context, discussing both holistic
# breach aspects and immediate settlements for the error, fundamentally connecting the
# regulations for the pertinent evaluation.
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous
# two-hand touch and, thinking that the race is over, pushes back from the wall on their
# back to read the scoreboard. At this point, realizing that the race is only halfway over,
# the swimmer returns to the wall, pushes off on the breast, and completes the required
# distance in good form. What call, if any, should be made?
# >>>Evaluation Time: 13.42 seconds
# >>>Relevance: retrieval_helpfulness False,
# In this situation, a swimmer mistakenly treated the 50-yard mark in a 100-yard
# breaststroke as a finish, flipped onto their back, and then corrected themselves to finish
# the race in proper form. The input is focused on determining whether this incident
# contravenes the rules of a breaststroke event and requires a disqualification.
#
# ###
# Relevant Context and Facts Needed
# 1. **Breaststroke Rules:** This includes rules regarding
# stroke, turns, and finish for breaststroke.
# 2. **Rules on Swimming on the Back:**
# Specifics regarding what constitutes a stroke violation in breaststroke if a swimmer ends
# up on their back.
# 3. **Disqualification Criteria:** Information about what actions or
# mistakes lead to disqualification.
#
# ### Retrieved Output Analysis
# **Chunk_1:** Contains
# general rules for different strokes but not specific rules relevant to the breaststroke or
# necessary for evaluation of the incident.
# - **Irrelevant.**
#
# **Chunk_2:** Provides
# detailed rules for breaststroke, especially that the body must remain on the breast
# throughout the swim except at turns. However, it doesn't specifically elaborate on a
# mistake in the middle of the pool or criteria for disqualification.
# - **Partially
# Relevant.**
#    - Relevant text: “It is not permitted to roll onto the back at any time
# except at the turn after the touch..."
#
# **Chunk_3:** Contains specifications for butterfly
# and backstroke, which are not directly related to the breaststroke rules pertinent in this
# scenario.
# - **Irrelevant.**
#
# **Chunk_4:** Contains rules for a forward start, which is
# immaterial to back-and-forth movement in the pool concerning our input.
# - **Irrelevant.**
# ### Missing Information
# - Criteria for what constitutes a disqualification due to error
# mid-race, such as mistakenly swimming on the back.
# - Specific reference to how a
# correction like returning to breast from back should be treated by officials.
#
# ###
# Conclusion
# The retrieved outputs collectively fail to provide clear guidance on whether
# the swimmer should be disqualified based on the scenario described, but chunk_2 does offer
# partial relevance regarding breaststroke position requirements.
#
# Thus, the score should
# be: false.
#
# Query: A swimmer swims the breaststroke in a way that their hands are completely underwater when
# they are pushed forward together from their breast.
# >>>Evaluation Time: 6.65 seconds
# >>>Relevance: retrieval_helpfulness False,
# Upon evaluating the content of 'chunk_1', several observations can be made concerning its
# relevance to the input description concerning a swimmer in the breaststroke:
#
# 1.
# **Breaststroke Technique**: The input describes a swimmer pushing their hands forward
# underwater during the breaststroke. This specific detail is crucial in determining
# adherence to official breaststroke rules.
#    - **Relevance in the Document**: The document
# discusses swimming regulations, particularly focusing on different strokes like butterfly
# and backstroke, but does not address specific rules surrounding the hand movement in
# breaststroke.
#
# 2. **Information Pertaining to the Breaststroke**:
#    - **Clause of
# Irrelevance**: The majority of the document pertains to the butterfly and backstroke
# strokes. The relevant portion concerning the breaststroke (how hands must move during the
# stroke) is absent here, which is essential for determining if the described hand movement
# conforms to official guidelines.
#
# 3. **Relevance Criteria**:
#    - The document provides a
# broader context about swimming regulations, and some protocols apply generally to other
# strokes as well. However, without any mention of the specific breaststroke rules regarding
# hand movement, it does not help verify or provide useful context in line with the input
# situation.
#
# In summary, the information within 'chunk_1' is predominantly irrelevant to
# assessing whether the specified hand movements align with breaststroke rules due to its
# focus on other strokes and absence of direct guidelines for breaststroke.
#
# Thus, the
# score should be: false.
#
# Query: A swimmer swims the breaststroke in a way that their elbows are above the water line
# during the forward movement of the arms.
# >>>Evaluation Time: 3.89 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input describes a swimmer's technique in the breaststroke, specifically concerning the
# positioning of elbows during the forward movement of the arms. Useful facts and relevant
# context to respond to this input would include the correct technique for breaststroke arm
# movement, common mistakes in breaststroke form, and the rules in professional swimming
# regarding arm positioning for this stroke.
#
# In analyzing the retrieval output, however,
# it's clear there are no documents or information presented. This lack of information means
# none of the facts identified as needed to address the input properly are covered. There
# are no relevant insights about swimming techniques, common errors, or any swimming rules
# tailored to this particular situation.
#
# Thus, no part of the input's query is addressed,
# nor is there any mention of partially relevant but contextually helpful information.
# Consequently, the absence of any retrieved outputs means the response provides no utility
# or relevance to the initial input about breaststroke technique.
#
# Thus, the score should
# be: false.
#
# Query: A breaststroker’s head breaks the surface of the water during each cycle, however, the
# swimmer does not take a breath even if the head breaks the surface.
# >>>Evaluation Time: 6.46 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input discusses a scenario in competitive swimming regarding a breaststroke swimmer
# whose head breaks the water's surface without taking a breath. To determine relevance, the
# outputs should ideally offer information such as:
#
# 1. **Important Facts Required**:
#    -
# Rules governing when a swimmer must take a breath in breaststroke events.
#    - Exceptions
# or strategic reasons for not taking a breath even if the head surfaces.
#    - Potential
# impacts on performance (e.g., increased speed or streamlined motion).
#
# 2. **Assessment of
# Provided Outputs**:
#    - The output list is empty, meaning no information whatsoever is
# provided to support, refute, or contextualize the input's scenario.
#    - Therefore, this
# lack of information means none of the relevant facts described above are addressed in full
# or in part.
#
# 3. **Conclusion**:
#    - Since the output list is completely empty, there is
# no information being retrieved that could either confirm nuances about breathlessness in
# breaststroke races or contradict the input scenario.
#
# Thus, the score should be: false.
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmwer is facing
# the starting end of the pool with one hand on the wall.
# >>>Evaluation Time: 7.89 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input describes a freestyle event where a swimmer starts in the water facing the
# starting end, with one hand on the wall. The goal is to assess whether provided outputs
# contain relevant information about this setup.
#
# 1. **Chunk 1:**
#    - Discusses an in-water
# forward start where the swimmer has a hand in contact with the wall.
#    - This is directly
# relevant to the input, aligning with the description of the start position.
#    -
# **Relevance:** Completely relevant.
#
# 2. **Chunk 2:**
#    - Contains extensive swimming
# rules but primarily about stroke mechanics and finishing.
#    - Briefly mentions forward
# starts but mainly in different stroke contexts.
#    - Only partially relevant due to its
# minor reference to starts.
#    - **Relevance:** Partially relevant.
#
# 3. **Chunk 3:**
#    -
# Mention of in-water forward start applicable to freestyle, which correlates directly with
# the input.
#    - **Relevance:** Completely relevant.
#
# 4. **Chunk 4:**
#    - Discusses
# various strokes, rules about arm and leg coordination, but focus is not on the in-water
# start.
#    - The description doesn’t pertain directly to the input scenario.
#    -
# **Relevance:** Irrelevant.
#
# 5. **Chunk 5:**
#    - Predominantly details about
# disqualification and starts in breaststroke, not touching upon the freestyle start setup.
# - Does not address any aspect of starting as described in the input.
#    - **Relevance:**
# Irrelevant.
#
# To resolve the prompt effectively, outputs should specifically address the
# position and hand placement of swimmers at the start of a freestyle event. Thus, the score
# should be: True, as at least some retrieved content is directly relevant to answering the
# input and supports an understanding of the rules associated with the described start
# position.
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmer is facing
# the other end of the pool with one hand on the wall.
# >>>Evaluation Time: 7.42 seconds
# >>>Relevance: retrieval_helpfulness True,
# The given input describes a particular start position of a swimmer in the water during a
# freestyle event, specifically focusing on the swimmer's orientation and hand position. To
# evaluate the relevance of retrieved documents, we assessed:
#
# ### List of Relevant
# Information for the Input:
# 1. **Start Position Description:** Details on swimmer's
# orientation and hand position for in-water starts.
# 2. **Freestyle Event Rules:** Any
# specifics about rules during freestyle events related to starting the race.
#
# ### Analysis
# of Each Retrieved Document
# - **Chunk 1:**
#   - Contains relevant information stating the
# swimmer must be in contact with the wall while starting, facing the course. This
# information aligns closely with the input about the start position.
#   - **Conclusion:**
# Fully relevant.
#
# - **Chunk 2:**
#   - Provides extensive information on different aspects
# of race starts, turns, and finishes, but much of it covers general competitive swimming
# rules outside the in-water start.
#   - Lacks specific emphasis on the scenario of a swimmer
# starting in the water with one hand on the wall, hence, partially relevant for the input
# query.
#   - **Conclusion:** Partially relevant.
#
# - **Chunk 3:**
#   - Briefly mentions in-
# water forward start allowance, not elaborating on the hand position or orientation.
#   -
# **Conclusion:** Partially relevant.
#
# ### Final Assessment
# The retrieved outputs contain
# mainly relevant information concerning the start position of the swimmer in freestyle
# events, though some retrieved content is not directly addressing the unique specifics of
# the input case. However, a substantial portion speaks to applicable rules, thus offering
# helpful context.
#
# Thus, the score should be: true.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is facing
# the other end of the pool with one hand on the wall.
# >>>Evaluation Time: 10.33 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input describes a situation where a swimmer is performing a start in a butterfly event
# with specific instructions about the in-water start position. The relevant context needed
# includes competitive swimming rules, specifically for butterfly events.
#
# 1. **Analyzing
# Outputs:**
#
#   - **Chunk 1**:
#     - This describes an in-water forward start rule, which
# is relevant to the input situation as it confirms the proper stance required when a
# swimmer starts facing the other end of the pool.
#     - This is partially relevant as it
# matches the input's description of needing one hand on the wall while facing 'the course.'
# - **Chunk 2**:
#     - Contains comprehensive details about rules specific to the butterfly
# event, such as the start, stroke, kick, turns, and finish.
#     - Provides contextual
# relevance by detailing how the start should be performed ('The forward start shall be
# used'), indicating a general requirement but does not specify 'in-water start'.
#     -
# Partially addresses the requirement as it mentions the start but does not directly refer
# to in-water specifics requested in the input.
#
#   - **Chunk 3**:
#     - Confirms that an
# in-water forward start is allowed in butterfly events alongside other strokes.
#     - This
# content is directly relevant as it provides explicit confirmation that corresponds with
# the input instructions.
#
# 2. **Conclusion:**
# - Chunks 1 and 3 provide information directly
# relevant to the input situation by specifying the start rules applicable to the scenario
# described. Chunk 2 offers extensive details about the event, partially encompassing the
# input's requirements but lacks specific details directly addressing the start as in water.
# Thus, the score should be: true.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer has one hand
# on the wall looking away from the starting block.
# >>>Evaluation Time: 10.00 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input describes a specific start condition for swimmers during a butterfly event. The
# retrieved outputs should contain relevant information about the butterfly stroke start
# that can help further understand or clarify the conditions for such a start.
#
# 1.
# **Analyzing Chunk 1:**
#    - **Relevance:** This mentions an in-water forward start
# condition with requirements for hand placement and direction, relevant to butterfly
# starts.
#    - **Coverage:** Partially addressed as the description of hand placement
# aligns with the input.
#
# 2. **Analyzing Chunk 2:**
#    - **Relevance:** Provides in-depth
# butterfly stroke details, including starts and turns. However, relevant aspects regarding
# backward facing during a start have limited coverage.
#    - **Coverage:** Partially
# addressed regarding general butterfly starting rules but not specifically about backward
# positioning against the block.
#
# 3. **Analyzing Chunk 3:**
#    - **Relevance:** Confirms
# that an in-water forward start is allowed for butterfly, aligning with input details.
#    -
# **Coverage:** Full confirmation of start allowance, though missing specific backward-
# facing detail.
#
# 4. **Analyzing Chunk 4:**
#    - **Relevance:** Contains rules concerning
# starts and strokes not specifically aligned with the butterfly event or the described
# start facing backward.
#    - **Coverage:** Irrelevant to the specific details of butterfly
# start conditions. Mostly about general misconduct and breaststroke details.
#
# **Missing
# Facts:** None of the outputs fully cover the backwards-facing aspect mentioned in the
# input, which is crucial to understanding the specific start condition described.
# **Conclusion:** Outputs do bear some relevant overlap concerning in-water forward starts
# and butterfly starts. However, specific essential details about the swimmer's position
# facing away are incompletely covered.
#
# Thus, the score should be: false.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is looking
# at the opposite end of the pool.
# >>>Evaluation Time: 7.87 seconds
# >>>Relevance: retrieval_helpfulness True,
# ### Information Needed to Answer the Input:
# 1. **Positioning Requirements:** Details about
# how a swimmer should be positioned at the start of a butterfly event.
# 2. **Compliance with
# Rules:** Explanation of rules regarding starting techniques for butterfly events.
#
# ###
# Evaluation of Retrieved Outputs:
#
# #### **Chunk 1:**
# - **Direct Relevance:**
#   - Provides a
# relevant description of the swimmer's position: "the swimmer shall have at least one hand
# in contact with the wall and facing away from the starting end toward the course." This
# directly fits the query about how a swimmer should initially position themselves in a
# butterfly event.
# - **Partial Contextual Help:**
#   - Further contextual help in
# understanding or visualizing how a swimmer is oriented for a butterfly start.
# -
# **Irrelevance:**
#   - The output is directly relevant and does not contain unrelated data.
# #### **Chunk 2:**
# - **Direct Relevance:**
#   - States that an in-water forward start is
# allowed for butterfly events: "An in-water forward start is allowed for butterfly,
# breaststroke, and freestyle." This confirms the permissibility of the technique for
# butterfly events.
# - **Partial Irrelevance:**
#   - While tangentially mentioning
# breaststroke and freestyle, this inclusion does not shift the focus from the inquiry about
# butterfly events.
#
# ### Overall Assessment:
# Both chunks provide helpful insights into the
# input, addressing the inquiries about positioning and regulation for a butterfly event.
# The inclusion of positioning guidelines and start allowances underlines their relevance
# across different swimming events.
#
# Thus, the score should be: true.
#
# Query: In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second
# 50m in backstroke, the third 50m starts swimming freestyle but then switches to
# breaststroke, and the last 50m in freestyle.
# >>>Evaluation Time: 8.56 seconds
# >>>Relevance: retrieval_helpfulness False,
# The task involves determining if the retrieved outputs are relevant to the question about
# the rules governing the order and styles of strokes for a 200m individual medley event
# based on the given input.
#
# **Analyzing Retrieved Outputs:**
#
# 1. **chunk_1**:
#    -
# **Relevant Information**:
#      - Provides details on individual medley rules,
# particularly the prescribed sequence of strokes: butterfly, backstroke, breaststroke, and
# freestyle.
#      - Describes freestyle guidelines indicating any stroke aside from the
# three IM strokes can be used.
#    - **Partial Insights**: Includes information about
# general stroke regulations and requirements for turns and finishes.
#
# 2. **chunk_2**:
#    -
# **Irrelevant Information**:
#      - Primarily comprises a list of competition events by age
# group which do not address the rules or the sequence in a 200m IM event.
#
# 3. **chunk_3**:
# - **Irrelevant Information**:
#      - Focuses on relay exchanges and long-distance
# swimming rules, neither of which pertains to the strokes sequence or rules of a 200m
# individual medley event.
#
# 4. **chunk_4**:
#    - **Irrelevant Information**:
#      -
# Discusses allowed starts in swimming, but lacks specifics on stroke sequence or
# requirements for an individual medley.
#
# **Conclusion**:
# - **Full Relevance**:
#   - Chunk 1
# is partially relevant and directly helpful in providing information about the stroke
# sequence in an individual medley event.
# - **Irrelevance**:
#   - Chunks 2, 3, and 4 do not
# provide the required information to answer the specific query related to the input.
#
# Thus,
# with most of the content being irrelevant, the score should be: **false**.
#
# Query: In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y
# in backstroke.
# >>>Evaluation Time: 8.85 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input describes a 100-yard freestyle event with unconventional strokes (butterfly and
# backstroke) for the first and last halves, respectively. Given the task, we must determine
# if the outputs provide useful rules or information relevant to addressing such an event
# setup:
#
# ### Analysis of Retrieved Outputs:
#
# **Chunk 1:**
# - **Relevant Information:**
# Describes allowable stroke techniques in freestyle and individual medley events. Explains
# legal positions during turns and finishes, and notes the order of strokes in an individual
# medley.
#   - **Partial Relevance:** The context of stroke rules for freestyle, even
# mentioning butterfly and backstroke, is partially helpful. However, it mainly discusses
# standard freestyle where any stroke but the named ones is permissible, contrasting the
# scenario where specific strokes are assigned.
#
# **Chunk 2:**
# - **Irrelevant Information:**
# Primarily discusses rules on relay starts and pool event procedures for long-distance
# swimming. Provides event details unrelated to the input query.
#
# **Chunk 3:**
# - **Partially
# Relevant Information:** Remarks on an in-water forward start for specific strokes, though
# lacking specific context about a swimmer transitioning from butterfly to backstroke within
# a freestyle context.
#
# ### Unaddressed Information:
#
# - Legalities or rules specific to
# implementing assigned strokes (i.e., butterfly and backstroke) in a supposed freestyle
# event are unmentioned.
# - No explicit mention on implications for the race start or
# continuity between differing strokes.
#
# ### Conclusion:
# Both relevant and irrelevant
# portions found, with none directly answering the intricacies of the described event, which
# may represent an exhibition or unregulated format. Thus, the outputs do not provide
# useful, direct information for answering the input fully.
#
# Thus, the score should be:
# false.
