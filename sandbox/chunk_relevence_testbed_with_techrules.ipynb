# %%
from langchain_chroma.vectorstores import Chroma
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

from openevals.llm import create_llm_as_judge
from openevals.prompts import RETRIEVAL_HELPFULNESS_PROMPT

import pandas as pd
import time

# %%
# Initialize embeddings model (ensure the same model used during creation)
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# Load the existing Chroma vector store
persist_directory = "../db/swim_rules_semantic"
vector_store = Chroma(persist_directory=persist_directory, embedding_function=embeddings)

# %% [markdown]
# ## Helper Functions

# %%
# Function to perform semantic search
def semantic_search(query, k=10):
    """
    Perform a semantic search on the Chroma vector store.

    Args:
        query (str): The query string to search for.
        k (int): The number of top results to retrieve.

    Returns:
        list: A list of documents matching the query.
    """
    results = vector_store.similarity_search_with_relevance_scores(query, k=k, score_threshold=0.4)
    chunks = [{"title": f"chunk_{chunk+1}", "content": result[0].page_content} for chunk, result in enumerate(results)]

    relevance = chunk_evaluator(inputs=query, outputs=chunks)

    print(f"num results: {len(results)}, {[result[1] for result in results]}")

    return relevance




chunk_evaluator = create_llm_as_judge(
    prompt=RETRIEVAL_HELPFULNESS_PROMPT,
    feedback_key="retrieval_helpfulness",
    model="openai:gpt-4o",
)

# %% [markdown]
# ## Test chunk retrieval

# %%
# %%time
# Example usage
queries = [
    "Prior to the start signal the swimmer is seen rocking back and forth.  Is this a disqualification?",
    "upon the command 'take your mark', the swimmer takes their starting position and just prior to the start signal, the swimmer is seen moving forward.",
    "What happens if a swimmer touches the wall with one hand in freestyle?",
    "what happens if a swimmer touches the wall with one hand in breaststroke?",
    "A swimmer is wearing a wetsuit in a swimming competition?",
    "During a freestyle event, a swimmer does a flip turn and touches the wall with only one foot.",
    "A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of the first arm stroke, both after the start and after the turn Should they be disqualified?",
    "In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?",
    "In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall on their back to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?",
    "A swimmer swims the breaststroke in a way that their hands are completely underwater when they are pushed forward together from their breast.",
    "A swimmer swims the breaststroke in a way that their elbows are above the water line during the forward movement of the arms.",
    "A breaststroker’s head breaks the surface of the water during each cycle, however, the swimmer does not take a breath even if the head breaks the surface.",
    "During a freestyle event, a swimmer starts in the water such that the swimmwer is facing the starting end of the pool with one hand on the wall.",
    "During a freestyle event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer has one hand on the wall looking away from the starting block.",
    "During a butterfly event, a swimmer starts in the water such that the swimmer is looking at the opposite end of the pool.",
    "In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second 50m in backstroke, the third 50m starts swimming freestyle but then switches to breaststroke, and the last 50m in freestyle.",
    "In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y in backstroke.",
]

relevance_list = []
for i, query in enumerate(queries):
    print(f"\nQuery: {query}")
    start_time = time.time()
    relevance = semantic_search(query)
    end_time = time.time()

    relevance["query"] = query
    relevance["evaluation_time"] = end_time - start_time
    relevance_list.append(relevance)

    print(f"completed {i+1} out of {len(queries)} queries")
# Out:
# Query: Prior to the start signal the swimmer is seen rocking back and forth.  Is this a disqualification?
# num results: 2, [0.43222538948755584, 0.42851414874192906]
# completed 1 out of 19 queries
#
# Query: upon the command 'take your mark', the swimmer takes their starting position and just prior to the start signal, the swimmer is seen moving forward.
# num results: 2, [0.4263217539760894, 0.41741996635412393]
# completed 2 out of 19 queries
#
# Query: What happens if a swimmer touches the wall with one hand in freestyle?
# num results: 3, [0.5160830061917044, 0.4516143727954164, 0.41716792209485676]
# completed 3 out of 19 queries
#
# Query: what happens if a swimmer touches the wall with one hand in breaststroke?
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 3, [0.513873848657147, 0.46893478877836237, 0.42539928590273146]
# completed 4 out of 19 queries
#
# Query: A swimmer is wearing a wetsuit in a swimming competition?
# num results: 0, []
# completed 5 out of 19 queries
#
# Query: During a freestyle event, a swimmer does a flip turn and touches the wall with only one foot.
# num results: 1, [0.4583698804089851]
# completed 6 out of 19 queries
#
# Query: A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of the first arm stroke, both after the start and after the turn Should they be disqualified?
# num results: 2, [0.5278120395398984, 0.4294021828400536]
# completed 7 out of 19 queries
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?
# num results: 4, [0.5146909669551838, 0.5091261499588964, 0.48396435495734724, 0.43532050465670646]
# completed 8 out of 19 queries
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous two-hand touch and, thinking that the race is over, pushes back from the wall on their back to read the scoreboard. At this point, realizing that the race is only halfway over, the swimmer returns to the wall, pushes off on the breast, and completes the required distance in good form. What call, if any, should be made?
# num results: 4, [0.5147741648341444, 0.5134805094659509, 0.49748670768673386, 0.4403896252614583]
# completed 9 out of 19 queries
#
# Query: A swimmer swims the breaststroke in a way that their hands are completely underwater when they are pushed forward together from their breast.
# num results: 1, [0.4097855222565371]
# completed 10 out of 19 queries
#
# Query: A swimmer swims the breaststroke in a way that their elbows are above the water line during the forward movement of the arms.
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 0, []
# completed 11 out of 19 queries
#
# Query: A breaststroker’s head breaks the surface of the water during each cycle, however, the swimmer does not take a breath even if the head breaks the surface.
# No relevant docs were retrieved using the relevance score threshold 0.4
# num results: 0, []
# completed 12 out of 19 queries
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmwer is facing the starting end of the pool with one hand on the wall.
# num results: 5, [0.653508654706495, 0.5076304425989419, 0.47857688255750197, 0.4035777129393675, 0.4009182467983301]
# completed 13 out of 19 queries
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.
# num results: 3, [0.613200174372203, 0.49437513230172014, 0.44327625356076283]
# completed 14 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is facing the other end of the pool with one hand on the wall.
# num results: 3, [0.6043454764719436, 0.4549280844658885, 0.4409715831109483]
# completed 15 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer has one hand on the wall looking away from the starting block.
# num results: 4, [0.6109770109969948, 0.45886894124220257, 0.4445723459548685, 0.41662523927343054]
# completed 16 out of 19 queries
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is looking at the opposite end of the pool.
# num results: 2, [0.452058485279235, 0.40671861559850164]
# completed 17 out of 19 queries
#
# Query: In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second 50m in backstroke, the third 50m starts swimming freestyle but then switches to breaststroke, and the last 50m in freestyle.
# num results: 4, [0.5423546831780368, 0.4186815418654285, 0.4168984351454781, 0.40467390199400877]
# completed 18 out of 19 queries
#
# Query: In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y in backstroke.
# num results: 3, [0.4613298114330566, 0.42678174468073726, 0.41189869961646]
# completed 19 out of 19 queries
# CPU times: user 519 ms, sys: 95.4 ms, total: 615 ms
# Wall time: 2min 19s

# %%
relevance_df = pd.DataFrame(relevance_list)
relevance_df = relevance_df[["key", "score", "evaluation_time", "query", "comment"]]
relevance_df
# Out:
#                       key  score  evaluation_time  \
# 0   retrieval_helpfulness  False         8.645577
# 1   retrieval_helpfulness   True         6.949613
# 2   retrieval_helpfulness   True         7.267491
# 3   retrieval_helpfulness   True         4.609283
# 4   retrieval_helpfulness  False         7.681885
# 5   retrieval_helpfulness   True         6.691034
# 6   retrieval_helpfulness  False         4.024399
# 7   retrieval_helpfulness   True         8.296239
# 8   retrieval_helpfulness   True        17.292914
# 9   retrieval_helpfulness  False         6.675392
# 10  retrieval_helpfulness  False         6.067825
# 11  retrieval_helpfulness  False         4.768078
# 12  retrieval_helpfulness   True         7.056856
# 13  retrieval_helpfulness   True         7.142723
# 14  retrieval_helpfulness   True         6.645498
# 15  retrieval_helpfulness   True         9.231432
# 16  retrieval_helpfulness  False         5.392947
# 17  retrieval_helpfulness   True         7.181325
# 18  retrieval_helpfulness  False         8.282364
#
#                                                 query  \
# 0   Prior to the start signal the swimmer is seen ...
# 1   upon the command 'take your mark', the swimmer...
# 2   What happens if a swimmer touches the wall wit...
# 3   what happens if a swimmer touches the wall wit...
# 4   A swimmer is wearing a wetsuit in a swimming c...
# 5   During a freestyle event, a swimmer does a fli...
# 6   A breaststroke swimmer moves their hands in a ...
# 7   In a 9-10 100 yard breaststroke event, a swimm...
# 8   In a 9-10 100 yard breaststroke event, a swimm...
# 9   A swimmer swims the breaststroke in a way that...
# 10  A swimmer swims the breaststroke in a way that...
# 11  A breaststroker’s head breaks the surface of t...
# 12  During a freestyle event, a swimmer starts in ...
# 13  During a freestyle event, a swimmer starts in ...
# 14  During a butterfly event, a swimmer starts in ...
# 15  During a butterfly event, a swimmer starts in ...
# 16  During a butterfly event, a swimmer starts in ...
# 17  In a 200m individual medley event, a swimmer s...
# 18  In a 100y freestyle event, the swimmer swims t...
#
#                                               comment
# 0   Upon reading and analyzing the input, the esse...
# 1   To address the input query regarding the swimm...
# 2   The input question is focused on the rules reg...
# 3   The input asks about the consequence if a swim...
# 4   The input seeks information about a swimmer we...
# 5   The input presents a scenario from a swimming ...
# 6   The input question is about whether a breastst...
# 7   In the input scenario, there is a 9-10 100 yar...
# 8   In evaluating the outputs against the rubric, ...
# 9   The retrieved output provides details on compe...
# 10  The input describes a specific technique in br...
# 11  In assessing the information retrieval for the...
# 12  The input mentions a scenario during a freesty...
# 13  To evaluate the relevance of the retrieved out...
# 14  The evaluations of the outputs for relevance a...
# 15  1. **Analyzing the Input:**\n   - A swimmer's ...
# 16  To evaluate the relevance of the output provid...
# 17  Upon evaluating the retrieved chunks of inform...
# 18  To determine the relevance of the retrieved ou...

# %%
relevance_df.evaluation_time.sum()
# Out:
# 139.90287446975708

# %%
relevance_df.describe()
# Out:
#        evaluation_time
# count        19.000000
# mean          7.363309
# std           2.772613
# min           4.024399
# 25%           6.356661
# 50%           7.056856
# 75%           7.982124
# max          17.292914

# %%
relevance_df.score.value_counts()
# Out:
# score
# True     11
# False     8
# Name: count, dtype: int64

# %%
import textwrap
for relevance in relevance_list:
    print(f"\nQuery: {textwrap.fill(relevance['query'], width=90,replace_whitespace=False)}")
    print(f">>>Evaluation Time: {relevance['evaluation_time']:.2f} seconds")
    print(f">>>Relevance: {relevance['key']} {relevance['score']},\n{textwrap.fill(relevance['comment'], width=90,replace_whitespace=False)}")
# Out:
# Query: Prior to the start signal the swimmer is seen rocking back and forth.  Is this a
# disqualification?
# >>>Evaluation Time: 8.65 seconds
# >>>Relevance: retrieval_helpfulness False,
# Upon reading and analyzing the input, the essential question posed is whether rocking back
# and forth before the start signal, in a swimming event, leads to disqualification. For
# relevance evaluation, one should look into the rules regarding swimmer actions before the
# start and potential misconduct or false start scenarios.
#
# 1. **Relevant Information:**
# - From 'chunk_1': It is mentioned that swimmers need to assume their starting position
# promptly, and a false start may lead to disqualification. However, it does not explicitly
# address whether pre-signal movement is seen as a legal infraction or grounds for
# disqualification. Also, the text suggests that an illegal starting position itself is not
# grounds for disqualification if the race proceeds.
#     - From 'chunk_2': Discusses
# potential penalties for deliberate delays or misconduct potentially related to the start,
# but doesn't specify if rocking back and forth could lead to disqualification.
#
# 2.
# **Relevant Contextual Help:**
#     - The documents provide insight into the procedures for
# starts and expectations of swimmer readiness, suggesting situations when a referee might
# issue a penalty.
#
# 3. **Irrelevant Information:**
#     - Both chunks contain extensive
# details on race procedures and disqualifications unrelated directly to the input, focusing
# more on post-start signals or other stroke specifics, which do not answer the input query.
# 4. **Informations Not Addressed:**
#     - None of the text explicitly addresses whether the
# act of rocking back and forth before the start signal is considered a disqualification.
# The input specifics might relate to procedures or standards not thoroughly outlined in the
# provided outputs, indicating a gap in the accessible rules.
#
# Considering the relevance
# rubric:
# - Outputs contain fragments of information that could potentially relate to
# understanding rules regarding starts but do not offer explicit clarity on whether pre-
# signal rocking leads to disqualification.
#
# Thus, the score should be: false.
#
# Query: upon the command 'take your mark', the swimmer takes their starting position and just
# prior to the start signal, the swimmer is seen moving forward.
# >>>Evaluation Time: 6.95 seconds
# >>>Relevance: retrieval_helpfulness True,
# To address the input query regarding the swimmer's movement just prior to the start
# signal, it is necessary to refer to the rules regarding the start of a swimming race and
# false starts. The input implies a possible rule violation (false start) as the swimmer
# moved forward before the start signal.
#
# 1. **Information directly relevant:**
#    - Both
# retrieved chunks mention procedures and rules around race starts:
#      - **Chunk 1**
# highlights what occurs with the command 'take your marks' and describes situations where a
# false start may lead to disqualification: "A Any swimmer initiating a start before the
# signal may be disqualified if the Referee independently observes and confirms the
# Starter’s observation that a violation occurred."
#      - This directly addresses the
# portion of the input about the swimmer moving before the start signal, which is tantamount
# to a false start.
#
# 2. **Information partially relevant:**
#    - **Chunk 2** mentions an in-
# water start, which, while related to starting procedures, does not directly address the
# situation described in the input since the input does not specify an in-water start.
#
# 3.
# **Information completely irrelevant:**
#    - No retrieved information is entirely
# irrelevant as all details pertain to starting procedures in swimming.
#
# 4. **Gaps:**
#    -
# The retrieved outputs do not include a direct mention of the consequences of the movement
# before the signal other than the potential disqualification if observed and confirmed by
# officials.
#
# Ultimately, the retrieved outputs offer significant details regarding starting
# positions and false start rules. They effectively address the input regarding the movement
# before the start signal, making them largely relevant. Thus, the score should be:
# **true**.
#
# Query: What happens if a swimmer touches the wall with one hand in freestyle?
# >>>Evaluation Time: 7.27 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input question is focused on the rules regarding touching the wall with one hand in
# freestyle swimming. To evaluate the relevance of each retrieved output:
#
# ### Analysis:
#
# -
# **Chunk 1**:
#   - Direct Relevance: None
#   - Partial Relevance: The content discusses
# starting positions, but does not directly address touching the wall during the race or
# finishes, making it irrelevant.
#   - Overall Relevance: Irrelevant.
#
# - **Chunk 2**:
#   -
# Direct Relevance:
#      - "Upon completion of each length, some part of the swimmer must
# touch the wall." (Relevant to swimming turns)
#      - "The swimmer shall have finished the
# race when any part of his person touches the wall after completing the prescribed
# distance." (Relevant to finishes in freestyle)
#   - Partial Relevance: Talks about
# positions during turns and finishes.
#   - Overall Relevance: Relevant.
#
# - **Chunk 3**:
#   -
# Direct Relevance:
#     - "Some part of the swimmer must break the surface..." touches on
# rule adherence but lacks context-specific to freestyle and touching during turns or
# finishes.
#   - Partial Relevance: Mentions about "body... on the breast," but this is
# related to different strokes.
#   - Overall Relevance: Mostly Irrelevant.
#
# ### Conclusion:
# Only the content in Chunk 2 contained necessary information that directly aids in
# answering the query regarding the rules of touching the wall in freestyle swimming. Chunks
# 1 and 3 failed to offer relevant information. Thus, the overall output does meet the
# rubric criteria of containing relevant fetched outputs, considering partially relevant
# information extends the understanding on touch rules.
#
# Thus, the score should be: true.
#
# Query: what happens if a swimmer touches the wall with one hand in breaststroke?
# >>>Evaluation Time: 4.61 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input asks about the consequence if a swimmer touches the wall with one hand in
# breaststroke. A relevant answer should address whether this action is permitted or if it
# leads to disqualification.
#
# Analyzing the outputs:
#
# 1. **chunk_1**: Discusses an in-water
# forward start but does not include information about the breaststroke rule on touching the
# wall with one or both hands.
#    - **Relevance:** Completely Irrelevant (specific to start
# protocols, not the queried breaststroke rule)
#
# 2. **chunk_2**: Provides detailed rules for
# breaststroke, emphasizing that both hands must touch the wall simultaneously at turns and
# the finish.
#    - **Relevance:** Directly Relevant (clearly states the requirement for
# simultaneous two-hand touch, indicating touching with one hand is not allowed and may lead
# to disqualification)
#
# 3. **chunk_3**: Includes a section specifically on breaststroke
# rules, reiterating the requirement for a two-hand touch at each turn and finish. This
# matches the factual need for understanding disqualification criteria.
#    - **Relevance:**
# Directly Relevant (reinforces the rule that both hands must touch simultaneously)
#
# In
# summary, chunks 2 and 3 provide substantial and correct information to address the query
# about breaststroke touch rules. Chunk 1 does not contribute relevant information.
#
# Thus,
# the score should be: true.
#
# Query: A swimmer is wearing a wetsuit in a swimming competition?
# >>>Evaluation Time: 7.68 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input seeks information about a swimmer wearing a wetsuit during a swimming
# competition. To determine relevance, one needs to consider:
#
# 1. **Rules and Regulations**:
# Information regarding whether the competition allows wetsuits, as rules can vary
# significantly based on the type of event (e.g., open water, triathlons, etc.).
# 2.
# **Performance Impact**: Data or analysis on how a wetsuit might affect swimming
# performance, buoyancy, or thermal regulation.
# 3. **Type of Competition**: Understanding
# what type of swimming competition it is (e.g., Olympic, local, open water, etc.) could
# inform whether a wetsuit is standard attire.
#
# For the given output:
#
# - **Relevant**:
# Any details regarding regulations on wetsuits in competitions, thermal benefits of
# wetsuits, and their impact on swimming speed or buoyancy.
# - **Partially Relevant**:
# General information about wetsuits that may not directly mention competitions but includes
# factors like material and design that could impact performance.
# - **Irrelevant**:
# Information entirely unrelated to both swimming competitions and wetsuits.
#
# The output
# provided is an empty list, which means there are no retrieved documents to evaluate.
# Therefore, no consideration was given to the factors mentioned above in determining the
# relevancy to the input. Additionally, there is no context provided about wetsuits,
# swimming regulations, or performance, which renders it completely irrelevant to the input.
# Thus, the score should be: false.
#
# Query: During a freestyle event, a swimmer does a flip turn and touches the wall with only one
# foot.
# >>>Evaluation Time: 6.69 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input presents a scenario from a swimming competition where a swimmer uses a flip turn
# during a freestyle event, touching the wall with only one foot. To evaluate its relevance,
# we need information regarding turn regulations specific to freestyle swimming and any
# rules regarding wall touches.
#
# Upon analysis, the provided output primarily contains
# detailed excerpts from swimming competition rules. It includes information on both
# touching the wall and flip turn mechanics:
#
# - The rule excerpt ("[T]he swimmer must touch
# the wall" and "[U]pon completion of each length the swimmer must touch the wall") directly
# confirms that a wall touch is mandatory for freestyle events, aligning with the input
# scenario.
# - Details are included about general freestyle regulations (e.g., being
# completely submerged during the turn is allowed), which contextualizes acceptable actions
# during a flip turn.
# - However, there is no explicit mention if touching the wall with one
# foot is sufficient. Nonetheless, the rule states that "some part of the swimmer must touch
# the wall," which seems to imply that touching with a foot would satisfy the rule.
#
# While
# the output doesn't explicitly address whether "touching with one foot" is permitted, the
# indication that any part of the body may touch in freestyle provides a contextually
# relevant and partially applicable response to whether a single foot touch is adequate.
# Thus, the gathered information is directly related to the rule compliance of the action
# described in the input and offers a partial answer based on included rules. The output
# displays relevance by providing rule context that reasonably implies compliance, even if
# it doesn't explicitly verify every aspect.
#
# Thus, the score should be: true.
#
# Query: A breaststroke swimmer moves their hands in a sculling or flipper movement at the end of
# the first arm stroke, both after the start and after the turn Should they be disqualified?
# >>>Evaluation Time: 4.02 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input question is about whether a breaststroke swimmer would be disqualified for using
# a sculling or flipper arm movement at the end of the first arm stroke after the start and
# turn. Relevant facts needed to address this input include breaststroke rules, particularly
# concerning arm movement, strokes, and possible reasons for disqualification.
#
# Analyzing
# the output documents:
# - Both `chunk_1` and `chunk_2` contain rules about breaststroke
# swimming.
# - `chunk_1` addresses the rules for arm movement in breaststroke (saying arms
# must move simultaneously without alternating), which is somewhat relevant to the question
# of whether sculling could lead to disqualification.
# - `chunk_2` further repeats is mostly
# about butterfly and backstroke rules, which are irrelevant to breaststroke.
#
# The retrieved
# documents partially address the input concern about arm movements but don't explicitly
# mention "sculling or flipper movement." The absence of explicit reference and the focus on
# alternate swimming styles dilute the relevance.
#
# Thus, the score should be: false.
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous
# two-hand touch and, thinking that the race is over, pushes back from the wall to read the
# scoreboard. At this point, realizing that the race is only halfway over, the swimmer
# returns to the wall, pushes off on the breast, and completes the required distance in good
# form. What call, if any, should be made?
# >>>Evaluation Time: 8.30 seconds
# >>>Relevance: retrieval_helpfulness True,
# In the input scenario, there is a 9-10 100 yard breaststroke event. Given this context,
# several key facts determine the relevance of the provided outputs:
#
# 1. **Breaststroke
# Regulations**: These include rules for starts, strokes, turns, and finishes, which are
# essential for determining any violations or disqualifications.
#    - *Relevant facts from
# output chunk_2 (Breaststroke)* provide details about the proper form required during the
# race, including the necessity of a simultaneous two-hand touch at each turn and finish,
# and the stroke cycle required.
#
# 2. **Misconduct Considerations**: Any actions by a swimmer
# that can be construed as misconduct, such as leaving the race prematurely or not
# completing it properly.
#    - *Relevant facts from output chunk_2 (Deliberate
# Delay/Misconduct)* address potential disciplinary actions, such as deliberate delays or
# misconduct that could apply to the swimmer's action of stopping mid-race.
#
# 3.
# **Evaluations of Turns and Completions**: Provided rules on how turns are to be executed
# are directly applicable.
#    - Chunks provide information beneficial to assess if returning
# to the wall and continuing can be considered legal within the terms of a race.
#
# 4.
# **Missing Relevant Information**: Specific rules on what disqualifies a swimmer in the
# case of misunderstanding or mistake are incomplete. Insights from both regulatory rules
# and handling specific situational errors would be more useful.
#
# Each part of the outputs
# contains information related to the breaststroke rules, but there isn't an explicit
# confirmation on how an instance of mistakenly assuming a race has ended is handled.
# Various excerpts touch on swimming and race completion rules without covering errors of
# judgment related to race completion fully.
#
# Thus, the outputs provide an adequate partial
# context, addressing relevant breaststroke mechanics but failing to fully address the
# specific misconduct scenario presented by the input. Given the presence of partially
# relevant and related content, the score should be: **true**.
#
# Query: In a 9-10 100 yard breaststroke event, a swimmer completes 50 yards with a simulatenous
# two-hand touch and, thinking that the race is over, pushes back from the wall on their
# back to read the scoreboard. At this point, realizing that the race is only halfway over,
# the swimmer returns to the wall, pushes off on the breast, and completes the required
# distance in good form. What call, if any, should be made?
# >>>Evaluation Time: 17.29 seconds
# >>>Relevance: retrieval_helpfulness True,
# In evaluating the outputs against the rubric, we need to determine if the retrieved
# information from the outputs provides relevant context or direct relevance to the input's
# scenario involving a 100-yard breaststroke event.
#
# - **Key Context & Facts Needed:**
#   -
# In a breaststroke event, specific rules govern the swimmer's body position and actions
# when completing a turn or touching the wall.
#   - Any deviation from these rules (e.g.,
# turning onto the back during the race) likely results in disqualification.
#   - The
# scenario describes a swimmer who mistakenly believes a race is over halfway and therefore
# improperly positions themselves on their back.
#
# - **Analysis of Outputs:**
#   - **Output
# 'chunk_1':** Contains general rules related to various swimming strokes, but lacks
# specific mention of regulations applicable when mistakenly turning onto one's back mid-
# race in a breaststroke event.
#   - **Output 'chunk_2':** Details rules regarding
# breaststroke, including that during turns, the body must remain on the chest, directly
# addressing the input situation and potential for disqualification due to improper body
# position.
#   - **Output 'chunk_3':** Continues with rules relevant to the breaststroke,
# outlining specific scenarios regarding the rules of the stroke cycle. The information
# relates to nuances around the position and stroke cycle, supporting the idea that a
# deviation can result in a rule breach.
#   - **Output 'chunk_4':** Offers no additional
# relevant rules to the breaststroke scenario.
#
# - **Conclusion:**
#   - Relevant portions of
# the retrieved documents (particularly outputs from 'chunk_2' and 'chunk_3') provide
# substantial context about the rules governing a swimmer's actions and body orientation in
# a breaststroke event, which is essential when evaluating if the swimmer's error should
# result in a penalty.
#   - 'chunk_1' and 'chunk_4' were less relevant for the input,
# providing general rather than specific details pertinent to the situation.
#   - Overall,
# the necessary facts to answer the input are addressed.
#
# Thus, the score should be: true.
#
# Query: A swimmer swims the breaststroke in a way that their hands are completely underwater when
# they are pushed forward together from their breast.
# >>>Evaluation Time: 6.68 seconds
# >>>Relevance: retrieval_helpfulness False,
# The retrieved output provides details on competitive swimming rules related to different
# strokes, including breaststroke, but does not specifically address whether a swimmer's
# hands can remain fully submerged when pushed forward. The content predominantly focuses on
# regulations for the butterfly stroke and mentions the requirement for arms to move over
# the water rather than staying submerged. While the rules related to strokes, including the
# position of arms in butterfly, are mentioned, this information does not directly answer
# the specific query about hand position during the breaststroke as described in the input.
# Thus, while the content partly discusses related swimming rules, it lacks direct relevance
# to answering whether keeping hands fully underwater while moving them forward in
# breaststroke is permissible. Thus, the score should be: false.
#
# Query: A swimmer swims the breaststroke in a way that their elbows are above the water line
# during the forward movement of the arms.
# >>>Evaluation Time: 6.07 seconds
# >>>Relevance: retrieval_helpfulness False,
# The input describes a specific technique in breaststroke swimming, emphasizing that the
# elbows should be above the water during the arm's forward movement. The retrieved output
# presents an empty set of results, which means there is no information provided.
#
# 1.
# **Facts and Relevant Context Needed:**
#    - Proper technique for the breaststroke swimming
# style, emphasizing different phases of the stroke.
#    - Rules and regulations in
# competitive swimming regarding arm movement in breaststroke.
#    - Common errors in
# breaststroke and their corrections.
#    - Impact of incorrect arm movement on swimmer's
# performance.
#
# 2. **Analysis of Retrieved Document:**
#    - The retrieved output is an empty
# array, indicating that no information has been provided.
#
# 3. **Relevance Evaluation:**
# - **Directly Relevant Information:** No information is provided that directly addresses
# the input.
#    - **Partially Relevant Information:** Nothing partially relevant is present.
# - **Irrelevant Information:** The output is irrelevant as it contains no content.
#
# 4.
# **Information Need Determination:**
#    - None of the facts and relevant context identified
# in step 1 is addressed.
#
# 5. **Conclusion:**
#    - The output contains no useful information
# to help answer the input because it is empty. Thus, it has failed to meet the criteria for
# relevance.
#
# Thus, the score should be: False.
#
# Query: A breaststroker’s head breaks the surface of the water during each cycle, however, the
# swimmer does not take a breath even if the head breaks the surface.
# >>>Evaluation Time: 4.77 seconds
# >>>Relevance: retrieval_helpfulness False,
# In assessing the information retrieval for the given input about a breaststroker's
# breathing pattern, no retrieved output was provided in the response to evaluate based on
# the rubric.
#
# ### Analysis:
# 1. **Input Examination:**
#      - The input describes a
# swimming technique where a breaststroker's head comes above water, but no breath is taken.
# 2. **Relevance Assessment Steps:**
#     - Determine if materials provided give information
# regarding breaststroke technique, breathing patterns, or similar swimming dynamics that
# could help understand or corroborate the input statement.
#     - Look for any evidence or
# explanation within outputs that may clarify why a swimmer might choose not to breathe at
# specific points in the stroke.
#     - Identify breathing strategies and their impacts on
# swimming efficiency.
#
# 3. **Output Evaluation:**
#     - Since no outputs are given, there's
# no informational content to test against the criteria provided in the rubric.
#     -
# Without content, no logical connection, partial relevancy, or complete alignment can be
# observed or noted.
#
# 4. **Conclusion:**
#    - As there is no material to process, extracted
# facts or insights to improve understanding based on the criteria laid out cannot be
# realized.
#    - Missing data points or responses mean the retrieval was either
# unsuccessful, absent, or an error occurred.
#
# Thus, the score should be: false.
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmwer is facing
# the starting end of the pool with one hand on the wall.
# >>>Evaluation Time: 7.06 seconds
# >>>Relevance: retrieval_helpfulness True,
# The input mentions a scenario during a freestyle event where a swimmer starts in the water
# facing the starting end with one hand on the wall. To evaluate the relevance of the
# outputs:
#
# - **Relevant information from outputs:**
#   - Output from *chunk_1* is directly
# relevant as it explains the condition of having one hand in contact with the wall during
# an in-water forward start.
#   - Output from *chunk_3* is partially relevant as it confirms
# that an in-water forward start is acceptable for freestyle among other strokes.
#
# -
# **Irrelevant or superfluous information in outputs:**
#   - Outputs from *chunk_2, chunk_4,*
# and *chunk_5* contain rules about turns, touches, and different strokes, which don't
# directly contribute to the input scenario but don't conflict with it. They might be seen
# as related to general swimming competition rules, hence are somewhat relevant but provide
# excess details not needed.
#
# - **Information directly relevant:**
#   - The information in
# *chunk_1* confirming the hand on the wall condition.
#
# - **Information partially
# relevant:**
#   - The confirmation in *chunk_3* related to freestyle being a permissible
# context for an in-water start.
#
# - **Information irrelevant:**
#   - Details on turns, touch
# rules, and starts specific to other strokes found in *chunks 2, 4, and 5.*
#
# Thus, while
# superfluous information exists, key elements relevant to addressing the input scenario are
# found within the outputs. Thus, the score should be: TRUE.
#
# Query: During a freestyle event, a swimmer starts in the water such that the swimmer is facing
# the other end of the pool with one hand on the wall.
# >>>Evaluation Time: 7.14 seconds
# >>>Relevance: retrieval_helpfulness True,
# To evaluate the relevance of the retrieved outputs, the focus is on whether they provide
# information that is helpful to answer how a swimmer should start in a freestyle event
# while being in the water.
#
# 1. **Factual Context Needed: **
#     - In water start
# requirements for freestyle.
#     - Any specific rules or regulations pertaining to hands or
# body position during the start.
#
# 2. **Evaluation of Retrieved Outputs: **
#
#    - **Chunk 1:
# ** Provides a relevant detail: "For an in-water forward start, the swimmer shall have at
# least one hand in contact with the wall and facing away from the starting end toward the
# course." This is directly relevant to the input as it clarifies the starting position.
# - **Chunk 2: ** This chunk primarily discusses rules on turns and finishes across various
# swimming styles, as well as conditions of being submerged. It contains extensive
# superfluous information unrelated to the initial conditions of the race start. However,
# the mention of the forward start requirement aligns with a generalized understanding of
# starting conditions. Thus, it is partially relevant but not directly useful for the
# specific input query.
#
#    - **Chunk 3: ** This chunk states, "An in-water forward start
# is allowed for butterfly, breaststroke, and freestyle," which confirms that such a start
# is permissible across different strokes, including freestyle. This information is somewhat
# relevant, providing associated validation for the input setup.
#
# 3. **Conclusion: **
#    -
# All the retrieved outputs provide varying degrees of relevance to the input. Chunk 1 is
# directly applicable, chunk 2 contains partial relevance, and chunk 3 offers additional
# contextual validation. None are completely irrelevant.
#
# Thus, the score should be: true.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is facing
# the other end of the pool with one hand on the wall.
# >>>Evaluation Time: 6.65 seconds
# >>>Relevance: retrieval_helpfulness True,
# The evaluations of the outputs for relevance are as follows:
#
# 1. **Chunk 1:**
#    -
# **Relevance:** Highly relevant. It addresses the starting position for a butterfly event,
# noting the requirement for a forward start and hand contact with the wall. This directly
# matches the part of the input regarding the swimmer starting in the water facing the end
# of the pool.
#
# 2. **Chunk 2:**
#    - **Relevance:** Partially relevant. While it provides
# details about the butterfly stroke mechanics, such as body position and movement under
# water, it doesn't directly address the initial starting position covered in the input.
# However, it gives contextual information regarding what the swimmer can do after starting.
# 3. **Chunk 3:**
#    - **Relevance:** Partially relevant. It confirms that an in-water
# forward start is allowed for the butterfly stroke, which provides partial corroboration of
# the input's starting situation.
#
# **Analysis:**
# - **Fully Addressed Needs:** The need to
# verify the starting position in a butterfly event is fully addressed by Chunk 1.
# -
# **Partially Addressed Needs:** Additional context on the butterfly stroke, although not
# specifically required to understand the starting position, is available in Chunks 2 and 3.
# - **Unaddressed Needs:** No significant additional needs related to the starting position
# that require addressing.
#
# Thus, although not all chunks equally contribute to the starting
# position inquiry, the combined information helps in understanding the context and
# confirming the input scenario. Given that relevant insights and verifications are present,
# the score should be: true.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer has one hand
# on the wall looking away from the starting block.
# >>>Evaluation Time: 9.23 seconds
# >>>Relevance: retrieval_helpfulness True,
# 1. **Analyzing the Input:**
#    - A swimmer's start in a butterfly event where they are
# positioned in water, with one hand on the wall and facing away from the starting block.
# 2. **Relevant Context Needed:**
#    - Rules regarding in-water starts in butterfly events.
# - General mechanics and rules of the butterfly swimming stroke and start.
#
# 3. **Evaluation
# of Retrieved Outputs:**
#    - **Chunk 1:** Contains relevant information describing that
# for an in-water start, the swimmer should have one hand on the wall and face away from the
# starting end. This directly addresses the input's condition of having one hand on the wall
# and facing away from the starting block.
#    - **Chunk 2:** Contains detailed rules on the
# butterfly stroke, including starts, turns, and overall stroke mechanics. However, while
# comprehensive on the stroke, it doesn't specifically focus on in-water starts.
#    -
# **Chunk 3:** States that an in-water forward start is allowed for butterfly (relevant),
# breaststroke, and freestyle, confirming the inquiry about the start.
#    - **Chunk 4:**
# Contains mostly information on starter protocol and breaststroke mechanics, intermixed
# with some irrelevant content to the in-water start context.
#
# 4. **Conclusion:**
#    -
# Chunks 1 and 3 are deemed relevant as they contain information specific to the conditions
# described in the input, particularly the in-water start scenario for butterfly events.
# - Chunk 2, though rich in butterfly stroke information, is partially relevant as it
# doesn't directly address the in-water start query.
#    - Chunk 4 provides information
# largely irrelevant to the specific scenario in question.
#
# Thus, the score should be: true.
#
# Query: During a butterfly event, a swimmer starts in the water such that the swimmer is looking
# at the opposite end of the pool.
# >>>Evaluation Time: 5.39 seconds
# >>>Relevance: retrieval_helpfulness False,
# To evaluate the relevance of the output provided in relation to the input question, we
# need to map the requirements of answering the query to the information present in the
# retrieved documents.
#
# **Input Analysis:**
# - Query is about a swimmer starting a butterfly
# event in the water and facing the opposite end.
# - Requires information on the rules or
# conventions regarding in-water starts in butterfly events.
#
# **Fact and Context Needs:**
# 1.
# Rules for starting position in a butterfly event.
# 2. Whether it is permissible to face the
# opposite end in an in-water start.
#
# **Document Analysis:**
# 1. **Document - 'chunk_1':**
# - Relevant Info: Describes a rule about in-water forward starts, mentioning the swimmer
# must have one hand in contact with the wall and face toward the course.
#    - Relevance:
# Partially relevant as it addresses starting positions in water but doesn’t directly
# mention facing opposite ends.
#
# 2. **Document - 'chunk_2':**
#    - Relevant Info:
# Declares that in-water forward starts are allowed for butterfly events.
#    - Relevance:
# Partial relevance as it confirms the butterfly event but does not elaborate on facing the
# opposite end.
#
# **Conclusion:**
# - Both chunks partially address the input requirements by
# discussing in-water starts and confirming their allowance in butterfly events.
# - However,
# neither document directly confirms or elaborates on the legality or convention of facing
# the opposite end of the pool.
#
# Thus, the score should be: false.
#
# Query: In a 200m individual medley event, a swimmer swims the first 50m in butterfly, the second
# 50m in backstroke, the third 50m starts swimming freestyle but then switches to
# breaststroke, and the last 50m in freestyle.
# >>>Evaluation Time: 7.18 seconds
# >>>Relevance: retrieval_helpfulness True,
# Upon evaluating the retrieved chunks of information against the input about the individual
# medley event, several observations can be made:
#
# 1. **Required Understanding:**
#    - The
# swimmer in the input has deviated from the standard swimming order and styles outlined for
# a 200m individual medley. The medley typically requires swimming the butterfly,
# backstroke, breaststroke, and freestyle in sequential order.
#
# 2. **Relevant Information
# Present in Chunks:**
#    - **Chunk 1** provides detailed rules and order for an individual
# medley event, explicitly mentioning the requirement for each stroke's sequence and
# execution. This directly relates to the deviation (freestyle followed by breaststroke)
# mentioned in the input.
#
# 3. **Irrelevant or Peripheral Information:**
#    - **Chunks 2 and
# 3** mostly discuss event types, development competitions, and longer-distance swimming
# protocols, which don't relate directly to understanding or evaluating the actions
# performed in the specific medley event described in the input.
#    - **Chunk 4** provides a
# minor piece of operational information about allowable starts, which doesn't apply to the
# question about the stroke order or style changes.
#
# 4. **Conclusion:**
#    - The core
# relevant information regarding the sequence and rules of individual medleys is adequately
# addressed in Chunk 1. However, the rest contain peripheral details or information that
# doesn't contribute directly.
#
# Thus, the score should be: true.
#
# Query: In a 100y freestyle event, the swimmer swims the first 50y in butterfly and the last 50y
# in backstroke.
# >>>Evaluation Time: 8.28 seconds
# >>>Relevance: retrieval_helpfulness False,
# To determine the relevance of the retrieved outputs, we analyze how well they address the
# scenario of a swimmer competing in a 100-yard freestyle event using butterfly for the
# first 50y and backstroke for the last 50y.
#
# **Relevant Information Needs:**
# -
# Confirmation of freestyle rules that allow for any swimming stroke.
# - Guidelines regarding
# transitioning between strokes in a freestyle race.
# - Clarification if individual medley
# rules apply.
# - General competition rules relevant to the event format.
#
# **Assessment of
# Retrieved Outputs:**
#
# **Chunk 1:**
# - Highly relevant as it discusses freestyle competition
# rules, allowing any stroke except during certain medley events.
# - Provides guidelines on
# touches and turns relevant when considering transitions between strokes.
# - However, it
# focuses more on individual medley specifics, which are not directly applicable to a
# freestyle event where a swimmer chooses strokes.
#
# **Chunk 2:**
# - Contains irrelevant
# details about relay exchanges and pool events larger than 100 yards, which do not impact
# the inquiry regarding a 100-yard freestyle event.
# - Provides no significant information
# applicable to the description of the swimmer's actions.
#
# **Chunk 3:**
# - Offers a mention
# of starting procedures for various strokes, which is marginally relevant.
# - Does not
# directly discuss the swimming strokes sequentially in a single freestyle event.
#
# Overall
# Analysis:
# - The extracted information pertinent for analyzing the swimmer's actions mainly
# stems from Chunk 1. Although chunk 3 offers some related starting rules, the transition
# between strokes during a freestyle event isn't distinctly elucidated in the outputs.
# -
# Chunks 2 & 3 predominantly present content irrelevant to the swim event described.
#
# Thus,
# the score should be: False.
